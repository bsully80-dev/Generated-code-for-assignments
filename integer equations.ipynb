# %%
def main():
    x = get_int()
    print(f"x is {x}")

def get_int():
    while True:
        try:
            x = int(input("what is x?"))
        except ValueError: 
            print("x is not integer")
        else:
            break
    return x

main ()
# Out:
# what is x? sad
# x is not integer
# what is x? 10
# x is 10

# %%
def main():
    x = get_int()
    print(f"x is {x}")

def get_int():
    while True:
        try:
            x = int(input("what is x?"))
        except ValueError: 
            print("x is not integer")
        else:
            return x
        

main ()
# Out:
# what is x? b
# x is not integer
# what is x? d
# x is not integer
# what is x? b
# x is not integer
# what is x? 45
# x is 45

# %%
def main ():
    x = get_int()
    print(f"x is {x}")
def get_int():
    while True: 
        try:
            return int(input("what is x?"))
        except ValueError: 
            print("x is not an integer")

main()
# Out:
# what is x? t
# x is not an integer
# what is x? 6
# x is 6

# %%
def main ():
    x = get_int()
    print(f"x is {x}")

def get_int():
    while True: 
        try:
            return int(input("what is x?"))
        except ValueError: 
            pass

main()
# Out:
# what is x? 6
# x is 6

# %%
x= 10
y= 5


try: 
    z = x+Ydef
# Out:
# divide by zero
# divide operation

# %%
try: 
    num = int(input("enter a number:"))
    result = 10/num
    print("result",result)
except ValueError:
    print ("invalid input")
except ZeroDivisioError: 
    print ("you can not divide by zero")
finally: 
    print("operation complete")
# Out:
# enter a number: 0
# operation complete
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 10
#       8     print ("you can not divide by zero")
#       9 finally:
# ---> 10     print("operation complete")
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       6     print ("invalid input")
#       7 except ZeroDivisioError:
#       8     print ("you can not divide by zero")
#       9 finally:
# ---> 10     print("operation complete")
#
# NameError: name 'ZeroDivisioError' is not defined
