# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.10.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: defusedxml in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (0.7.1)
# Collecting click (from nltk>=3.9->textblob)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk>=3.9->textblob)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk>=3.9->textblob)
#   Downloading regex-2026.7.10-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk>=3.9->textblob)
#   Downloading tqdm-4.68.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 3.3 MB/s  0:00:00
# Downloading nltk-3.10.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 18.5 MB/s  0:00:00
# Downloading regex-2026.7.10-cp314-cp314-win_amd64.whl (280 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading tqdm-4.68.4-py3-none-any.whl (676 kB)
#    ---------------------------------------- 0.0/676.6 kB ? eta -:--:--
#    ---------------------------------------- 676.6/676.6 kB 16.0 MB/s  0:00:00
# Installing collected packages: tqdm, regex, joblib, click, nltk, textblob
#
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    --------------------------------- ------ 5/6 [textblob]
#    --------------------------------- ------ 5/6 [textblob]
#    ---------------------------------------- 6/6 [textblob]
#
# Successfully installed click-8.4.2 joblib-1.5.3 nltk-3.10.0 regex-2026.7.10 textblob-0.20.0 tqdm-4.68.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

print("imported successfully")
# Out:
# imported successfully

# %%
class ChatBot:
    
    def __init__ (self):
    
        self.intents={
        "hours":{
            "keywords":["hours", "open","close"],
            "response": "We are open from 9AM to 5PM, Monday to Friday."
        }, 
        "return":{
            "keywords":["refund","moneyback","return"],
            "response": "I would be happy to help you process your return. Let me transfer you to to a live agent."

        }
    }

    def get_response(self,message):
        message = message.lower()
        for intent_data in self.intents.values(): 
            if any(word in message for word in intent_data["keywords"]):
                return intent_data["response"]

        sentiment = TextBlob(message).sentiment.polarity

        return ("That's great to hear" if sentiment > 0 else
                "I'm so sorry to hear that. How can I help?" if sentiment < 0 else
                "I see. Can you tell me more about that")


    def chat(self): 
        print("ChatBot: Hi, how can I help you today?")
        while (user_message := input("You:").strip().lower()) not in ['exit', 'quit', 'bye']:
            print(f"\nChatbot: {self.get_response(user_message)}")
        print("Chatbot: Thank you for chatting. Have a great day!")

# %%
ChatBot().chat()
# Out:
# ChatBot: Hi, how can I help you today?
# You: when is customer service open?
# Chatbot: We are open from 9AM to 5PM, Monday to Friday.
# You: bye
# Chatbot: Thank you for chatting. Have a great day!
