# %%
name = input("Name:")
house = input("House:")
print(f"{name} from {house}")
# Out:
# Name: Brian Stoughton
# House: Stoughton
# Brian Stoughton from Stoughton

# %%
def main():
    name = get_name()
    house = get_house()
    print (f"{name} from {house}")

def get_name():
    return input("Name:")

def get_house():
    return input("House:")

# %%
main()
# Out:
# Name: Brian
# House: Stoughton
# Brian from Stoughton

# %% [markdown]
# def main():
#     name,house = get_student()
#     print(f"{name} from {house}")
#
# def get_student():
#     name = input("Name:")
#     house = input("house:")
#     return name,house
#
# main()

# %%
def main(): 
    name,house = get_student() 
    print(f"{name} from {house}")

def get_student(): 
    name = input("Name:") 
    house = input("house:") 
    return name,house

main()
# Out:
# Name: Brian
# house: Stoughton
# Brian from Stoughton

# %%
def main():
    student = get_student()
    print(f"{student[0]} from {student[1]}")

def get_student():
    name = input("Name:")
    house _ input("House:")
    return (name,house)

# %%
main()
# Out:
# Name: Brian
# house: Boston
# Brian from Boston

# %%
def main(): 
    student = get_student()
    if student[0]==Harry:
        student[1]=Julian
    print(f"{student[0]} from {student[1]}")

def get_student():
    name = input("Name:")
    house = input("House:")
    return [name,house]

main()
# Out:
# Name: Brian
# House: nyc
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 12
#       8     name = input("Name:")
#       9     house = input("House:")
#      10     return [name,house]
#      11
# ---> 12 main()
#      13
#
# Cell In[18], line 3, in main()
#       1 def main():
#       2     student = get_student()
# ----> 3     if student[0]==Harry:
#       4         student[1]=Julian
#       5     print(f"{student[0]} from {student[1]}")
#
# NameError: name 'Harry' is not defined

# %%
def main():
    student = get_student()
    if student['name']==Brian:
        student['house']=Stoughton
    print(f"{student['name']} from {student['house']}")

def get_student():
    student = {}
    student['name'] = input("Name:")
    return {"name":name,"house":house}

main()
# Out:
# Name: Brian
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 12
#       8     student = {}
#       9     student['name'] = input("Name:")
#      10     return {"name":name,"house":house}
#      11
# ---> 12 main()
#
# Cell In[25], line 3, in main()
#       1 def main():
#       2     student = get_student()
# ----> 3     if student['name']==Brian:
#       4         student['house']=Stoughton
#       5     print(f"{student['name']} from {student['house']}")
#
# NameError: name 'Brian' is not defined

# %%
class Student:
    name = "Brian"
    house = "Stoughton"

# %%
Student
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Student
#
# NameError: name 'Student' is not defined

# %%
Student.name="Jim"

# %%
Student.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 Student.name
#
# NameError: name 'Student' is not defined

# %%
class Car: 
    name="toyota"
    color="white"
    price=323423

# %%
Car.name
# Out:
# 'toyota'

# %%
Car.color
# Out:
# 'white'

# %%
Car.price
# Out:
# 323423

# %%
type(Car)
# Out:
# type

# %%
class Employee:
    name="Brian"
    age=45
    city="NYC"

# %%
Employee.name
# Out:
# 'Brian'

# %%
Employee.age
# Out:
# 45

# %%
Employee.city
# Out:
# 'NYC'

# %%
e1 = Employee()

# %%
e1.name
# Out:
# 'Brian'

# %%
e1.age
# Out:
# 45

# %%
e1.city
# Out:
# 'NYC'

# %%
class Employee: 
    name="Brian"
    age = 45

    def info(self):
        print(f"{self.name} and {self.age}")

# %%
Employee().info()
# Out:
# Brian and 45

# %%
e1 =Employee()
e1.name
# Out:
# 'Brian'

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age

# %%
s1 = Student("Brian",45)

# %%
s1.name
# Out:
# 'Brian'

# %%
s1.age
# Out:
# 45

# %%
s2 = Student("Dave",23)

# %%
s2.name
# Out:
# 'Dave'

# %%
s2.age
# Out:
# 23

# %%
class Car:
    def __init__(self,color,price):
        self.color = color
        self.price = price

    def __str__(self):
        return (f"{self.color} and {self.price}")

c1 = Car('white',23)
c2 = Car("black", 25)

# %%
c1.color
# Out:
# 'white'

# %%
c2.color
# Out:
# 'black'

# %%
print(c1)
# Out:
# <__main__.Car object at 0x000002351F3967B0>

# %%
class Bank: 
    def __init(self,name,bal):
        self.name=name
        self.bal=bal
    def deposit(self,amount):
        self.bal = self.bal+amount
        print(f"{amount} deposited")

a1 = Bank("Brian", 654546)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 9
#       5     def deposit(self,amount):
#       6         self.bal = self.bal+amount
#       7         print(f"{amount} deposited")
#       8
# ----> 9 a1 = Bank("Brian", 654546)
#
# TypeError: Bank() takes no arguments
